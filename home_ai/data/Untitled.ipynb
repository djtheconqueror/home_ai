# %%
import pandas as pd

data = {
    "city": ["New York", "Atlanta", "Miami"],
    "region": ["East", "South", "South"],
    "budget": [2800, 1800, 2200],
    "climate": ["Cold", "Warm", "Warm"],
    "pace": ["Fast", "Balanced", "Fast"],
    "culture": ["High", "Medium", "High"]
}

df = pd.DataFrame(data)
df.to_csv("cities.csv", index=False)
df
# Out:
#        city region  budget climate      pace culture
# 0  New York   East    2800    Cold      Fast    High
# 1   Atlanta  South    1800    Warm  Balanced  Medium
# 2     Miami  South    2200    Warm      Fast    High
