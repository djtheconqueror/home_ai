# %%
# Core Packages for All Projects
# !pip install pandas numpy scikit-learn matplotlib seaborn joblib python-dotenv --quiet

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Setup complete.")
